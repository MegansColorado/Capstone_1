# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
covid_df = pd.read_csv('data/california_covid_cases.csv')

# %%
covid_df.sort_values('date', ascending=False).head(20)
# Out:
#               county  totalcountconfirmed  totalcountdeaths  \
# 7144            Yolo               1002.0              29.0
# 2266       Mendocino                119.0               0.0
# 3705            Lake                122.0               1.0
# 5464      Sacramento               6217.0              92.0
# 479         Tuolumne                 68.0               0.0
# 6424  San Bernardino              21508.0             310.0
# 1438          Orange              27718.0             455.0
# 2386          Fresno               9124.0              91.0
# 239        San Mateo               4258.0             114.0
# 3809           Modoc                  0.0               0.0
# 3929          Tulare               6320.0             153.0
# 2506            Inyo                 36.0               1.0
# 5344     Los Angeles             143343.0            3932.0
# 2146      Santa Cruz                660.0               3.0
# 6664          Plumas                 16.0               0.0
# ...

# %%
#remove dates before May 12?

# %%
covid_df.groupby('county').agg({'newcountconfirmed':'mean','newcountdeaths':'mean'})
# Out:
#                  newcountconfirmed  newcountdeaths
# county
# Alameda                  71.791667        1.283333
# Alpine                    0.009259        0.000000
# Amador                    0.366667        0.000000
# Butte                     3.500000        0.033333
# Calaveras                 0.625000        0.000000
# Colusa                    1.125000        0.000000
# Contra Costa             43.716667        0.766667
# Del Norte                 0.500000        0.000000
# El Dorado                 2.825000        0.000000
# Fresno                   76.033333        0.758333
# Glenn                     1.533333        0.000000
# Humboldt                  1.508333        0.033333
# Imperial                 59.250000        1.233333
# Inyo                      0.300000        0.008333
# Kern                     59.625000        0.816667
# Kings                    24.216667        0.333333
# Lake                      1.025210        0.008403
# ...

# %%
# Out:
#        Unnamed: 0 Hillary Clinton Bernie Sanders Roque\nDe La Fuente  \
# 0             NaN             DEM            DEM                 DEM
# 1         Alameda          164889         153955                 249
# 2         Percent            51.5             48                 0.1
# 3             NaN             NaN            NaN                 NaN
# 4          Alpine             113            137                   0
# ..            ...             ...            ...                 ...
# 172          Yuba            2388           2771                   9
# 173       Percent            45.1           52.4                 0.2
# 174           NaN             NaN            NaN                 NaN
# 175  State Totals         2745302        2381722                8453
# 176       Percent            53.1             46                 0.2
#
#     Henry Hewes Keith\nJudd Michael Steinberg Willie Wilson Kevin M. Moreau  \
# ...
